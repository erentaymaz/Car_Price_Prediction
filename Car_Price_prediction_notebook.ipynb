# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("car_dataset.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.Owner.unique()
# Out:
# array([0, 1, 3])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# ## Pre-process Data

# %% [markdown]
# Burada geçen adımlar yayınlanırken de uygulanması gerekiyor. !

# %% [markdown]
# ## Feature Engineering

# %%
df.Year.max()
# Out:
# 2018

# %%
df.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df = df.drop("Car_Name", axis=1)
df["Year"] = df["Year"].max()-df["Year"]
df = pd.get_dummies(df,columns=["Fuel_Type",	"Seller_Type",	"Transmission"],drop_first=True) #One-hot encoding yapılmış.
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel
# 0       4           3.35           5.59       27000      0             False  \
# 1       5           4.75           9.54       43000      0              True
# 2       1           7.25           9.85        6900      0             False
# 3       7           2.85           4.15        5200      0             False
# 4       4           4.60           6.87       42450      0              True
# ..    ...            ...            ...         ...    ...               ...
# 296     2           9.50          11.60       33988      0              True
# 297     3           4.00           5.90       60000      0             False
# 298     9           3.35          11.00       87934      0             False
# 299     1          11.50          12.50        9000      0              True
# 300     2           5.30           5.90        5464      0             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                True                   False                 True
# 1               False                   False                 True
# 2                True                   False                 True
# 3                True                   False                 True
# 4               False                   False                 True
# ..                ...                     ...                  ...
# 296             False                   False                 True
# 297              True                   False                 True
# 298              True                   False                 True
# 299             False                   False                 True
# 300              True                   False                 True
#
# [301 rows x 9 columns]

# %%
X = df.drop("Selling_Price",axis=1)
y = df["Selling_Price"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler().fit(X)
#Min-max scaler ile normalizasyon işlemi yapılmıştır.

# %%
X=scaler.transform(X)

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor()
xgb_model.fit(X,y)
xgb_model.score(X,y)
# Out:
# 0.9999874602106124

# %%
y_pred= xgb_model.predict(X)

# %%
df["y_pred"] = y_pred

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
"r2",r2_score(y,y_pred), "rmse", mean_absolute_error(y,y_pred)**.5
# Out:
# ('r2', 0.9999874602106124, 'rmse', 0.11074364851358144)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X,y)
lr_model.score(X,y)
# Out:
# 0.8825741581640659

# %% [markdown]
# The best model is XGBoost.

# %% [markdown]
# ### Save the model and scaler

# %%
list(df.drop(["Selling_Price","y_pred"],axis=1).columns)
#Feature engineering ile elde dilen değerlerin bir listeye kaydedilmesi gerekiyor.
#Modelin öğretildiği özelliklerden sormak için
# Out:
# ['Year',
#  'Present_Price',
#  'Kms_Driven',
#  'Owner',
#  'Fuel_Type_Diesel',
#  'Fuel_Type_Petrol',
#  'Seller_Type_Individual',
#  'Transmission_Manual']

# %%
#inputs
model = xgb_model
scaler = scaler
selected_features = list(df.drop(["Selling_Price","y_pred"],axis=1).columns)

import joblib

# save the model
joblib.dump(model,open("xgb_model.joblib","wb")) #ilk olarak model kaydedildi

# save our scaler
joblib.dump(scaler,open("scaler.joblib","wb")) #İkinci olarak scaler kaydedildi.Model katmanında

# save column names (selected features)
joblib.dump(selected_features, open("features_list.joblib","wb"))#3.olarak da featuresler kaydedildi.

# %% [markdown]
# <!-- Joblib ile de yapılabilir Pickle ile de yapılabilir. -->

# %%
# #Save the model using pickle
# import pickle
# # save the model to disk
# pickle.dump(model, open(model_file_path, 'wb'))

# #Load the model
# model = pickle.load(open(model_file_path, 'rb'))

# #Saving a Keras model
# # Calling `save('my_model')` creates a SavedModel folder `my_model`.
# model.save("my_model")

# %% [markdown]
# ## Real-time Prediction

# %% [markdown]
# ### Load feature names

# %%
columns = joblib.load("features_list.joblib")
columns
# Out:
# ['Year',
#  'Present_Price',
#  'Kms_Driven',
#  'Owner',
#  'Fuel_Type_Diesel',
#  'Fuel_Type_Petrol',
#  'Seller_Type_Individual',
#  'Transmission_Manual']

# %% [markdown]
# ### Input new data

# %%
sample_one = [{
"Year":2014,
"Selling_Price":3.35,
"Present_Price":5.59,
"Kms_Driven":27000,
"Fuel_Type":"Petrol",
"Seller_Type":"Dealer",
"Transmission":"Manual",
"Owner":0
    }]

# %%
df_s = pd.DataFrame(sample_one)
df_s
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0  2014           3.35           5.59       27000    Petrol      Dealer  \
#
#   Transmission  Owner
# 0       Manual      0

# %%
df_s["Year"] = 2023-df_s["Year"]
df_s = pd.get_dummies(df_s).reindex(columns=columns, fill_value=0)
df_s
# Out:
#    Year  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0     9           5.59       27000      0                 0              True  \
#
#    Seller_Type_Individual  Transmission_Manual
# 0                       0                 True

# %% [markdown]
# ### Load Model and its data scaler

# %%
scaler = joblib.load(open("scaler.joblib","rb"))
model = joblib.load(open("xgb_model.joblib","rb"))
df_s = scaler.transform(df_s)

# %% [markdown]
# ### Predict

# %%
pred_price = round(model.predict(df_s)[0] * 10_000)
print(f"Your car's price: ${pred_price}")
# Out:
# Your car's price: $26922

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.3.2)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.26.3)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.23.4)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-15.0.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.9.0)
# Collecting tzlocal<6,>=1.1 (from streamlit)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.4)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/erentaymaz/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.4)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading referencing-0.33.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading rpds_py-0.18.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 1.5 MB/s eta 0:00:0000:0100:010m
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.9/996.9 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-15.0.0-cp39-cp39-macosx_11_0_arm64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.4 MB/s eta 0:00:0000:01
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 1.6 MB/s eta 0:00:0000:010:01
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.33.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp39-cp39-macosx_11_0_arm64.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: validators, tzlocal, toolz, toml, tenacity, smmap, rpds-py, pyarrow, mdurl, jinja2, click, blinker, attrs, referencing, pydeck, markdown-it-py, gitdb, rich, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed altair-5.2.0 attrs-23.2.0 blinker-1.7.0 click-8.1.7 gitdb-4.0.11 gitpython-3.1.42 jinja2-3.1.3 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 mdurl-0.1.2 pyarrow-15.0.0 pydeck-0.8.1b0 referencing-0.33.0 rich-13.7.0 rpds-py-0.18.0 smmap-5.0.1 streamlit-1.31.1 tenacity-8.2.3 toml-0.10.2 toolz-0.12.1 tzlocal-5.2 validators-0.22.0
